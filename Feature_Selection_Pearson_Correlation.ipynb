# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamKatyaan/MachineLearning/blob/master/Feature_Selection_Pearson_Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a57f0f3b-6727-498d-b808-787bf54866ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a57f0f3b-6727-498d-b808-787bf54866ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving house_data.csv to house_data.csv

# %%
#Loading the dataset
df = pd.read_csv("house_data.csv")

# %%
list = []

# %%
#Using Pearson Correlation
plt.figure(figsize=(14, 14))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Correlation with output variable
cor_target = abs(cor["price"])

# %%
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# price            1.000000
# bathrooms        0.525138
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# Name: price, dtype: float64

# %%
rf = relevant_features.drop("price")
rf
# Out:
# bathrooms        0.525138
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# Name: price, dtype: float64

# %%
list.append(rf)
list
# Out:
# [bathrooms        0.525138
#  sqft_living      0.702035
#  grade            0.667434
#  sqft_above       0.605567
#  sqft_living15    0.585379
#  Name: price, dtype: float64]

# %%
rf = pd.DataFrame(rf).reset_index()
rf.columns = ['Feature', 'PCC']
rf
# Out:
#          Feature       PCC
# 0      bathrooms  0.525138
# 1    sqft_living  0.702035
# 2          grade  0.667434
# 3     sqft_above  0.605567
# 4  sqft_living15  0.585379

# %%
plt.bar("Feature", "PCC", data= rf, color = "blue")
plt.xlabel("Feature")
plt.ylabel("PCC")
plt.title("Pearson Correlation Coefficient")
plt.show()

# %%
rf= rf.sort_values(by="PCC",ascending=False)
rf
# Out:
#          Feature       PCC
# 1    sqft_living  0.702035
# 2          grade  0.667434
# 3     sqft_above  0.605567
# 4  sqft_living15  0.585379
# 0      bathrooms  0.525138

# %%
# Graph In Descending Order
plt.bar("Feature", "PCC", data= rf, color = "blue")
plt.xlabel("Feature")
plt.ylabel("PCC")
plt.title("Pearson Correlation Coefficient")
plt.show()
